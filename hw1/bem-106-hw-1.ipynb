# %% [markdown]
# BEM 106: Homework 1
# # Installation and Preparation
#
# Hello! If you're viewing this notebook then you've successfully downloaded Anaconda. Good job!
#
# You can edit the contents of any cell by double-clicking it or pressing "Return" or "Enter". If you click on this cell, you will notice that I've used the "Markdown" mode, as opposed to "Code", to write this introduction. When you're done editing a cell, you can press "Shift-Return" (Mac) or "Shift-Enter" (Windows) to run the cell. When a cell has a number to the side that means that the cell has been executed (only in Code mode). The number tells you the order in which the cells were executed (i.e. cell [2] was executed after cell [1])
#
# There are other useful shortcuts that you should be aware of. I've included a list of them in the appendix of the HW1 description pdf file.
#
# Anaconda installs not only Python, but also a number of additional packages that we will use in this course.

# %% [markdown]
# ### Coding best practices
#
# You should always document your code with comments to help make your work readable and informative. For example, it is a good idea to write (in words) function inputs and outputs, or what the cells is accomplishing. You can put comments in your code by starting any line with '#'  - anything written in that line will be colored green.
#
# You can also easily comment/uncomment multiple lines. Just select multiple lines with your cursor and then press `Cmd and /` (`Ctrl and /` for Windows).
#
# After week 3, you will be writing complex web-scapring code that will contain blocks of code within other blocks, and you will need to change the indentation of multiple lines of code. You can indent multiple lines by selecting them and then pressing `Tab`. To de-indent, you press `Shift+Tab` instead.
#
# Finally, it is a good idea to split up your code into parts that can be run independenly. For example, you can use one cell to install the necessary packages, another one to read in the data, and a third one to transform the data or do analysis. Writing your code out in multiple cells also helps with debugging - you will know exactly which part of your code is throwing you the error. To create more cells, click the "+", second icon from the left.

# %%
# This is a comment inside a Code cell

# %% [markdown]
# ## Basic data types
#
# Python has eight built-in data types. Four of those are quite simple, in the sense that they can **store a single value**:
#
# * Integers
# * Floats
# * Booleans
# * Strings
#
#
# The other four are denoted collections because they can store arbitrary numbers of values. Python's four collection data types are:
#
# * Lists
# * Tuples
# * Sets
# * Dictionaries
#
# Now, let's start with one of the most basic data types, the integer.

# %% [markdown]
# ## Integers
#
# An Python integer is a **natural number**, i.e. the numbers you count.
#
# Python allows you to do basic arithmetic with integers whether you define variables or not. Those operation are represented using the same notation you saw on a calculator.

# %%
123 + 256

# %% [markdown]
# We can also store the result of an operation into a variable. The variable will store the evaluated answer, not the arithmetic expression.

# %%
first_result = 10 / 3
first_result

# %% [markdown]
# The division operator stores the answer that we are used to, which is $3.3\bar{3}$. If you want to maintain the integer type after division, you can use truncating division with `//` like this:

# %%
second_result = 10 // 3
second_result

# %% [markdown]
# Finally, to get the remainder, use the symbol *%*

# %%
4.2 % 2

# %% [markdown]
# ## Floats
#
# A Python float is a **rational number**.

# %%
new_float = 109.234
print(new_float)

# %% [markdown]
# To change an integer to a float or vice versa, we can cast the number using the data type name that we want to transform it to:

# %%
int(109.234)

# %% [markdown]
# However, it won't stay that way unless we assign it to a new a variable!

# %%
basic_int = 109
print( float(basic_int) )
print( type(basic_int) )

# %%
float_basic_int = float(109)
print( type(float_basic_int) )

# %% [markdown]
# ## Comparing numbers
#
# To compare the result of computations, we use the standard set of comparisons:

# %% [raw]
# !=
# ==
# <=
# >=
# <
# >

# %% [markdown]
# The $==$ allows us to check if one side of the operator is equal to the other side.

# %% [markdown]
# Python evaluates the expression and tells us that it is `True` if it is correct or `False` if it is incorrect.
#
# The $!=$ operator allows us to check if one side does not equal the other side:

# %% [markdown]
# The greater than, less than, greater than or equal to, and less than or equal to operators all work as we would expect.

# %% [markdown]
# ## Booleans
#
# A Python Boolean is what is math is called a **logical variable** The Boolean data type is primarily associated with conditional statements (if/then), which allow different actions and change control flow depending on whether a programmer-specified Boolean condition evaluates to `True` or `False`.

# %%
first = 1
second = 2
third = first + second

print(third==3)

# %% [markdown]
# ## Strings
#
# A Python string is an ordered sequence of characters.

# %%
bem = "bem106"
print(bem)
# Out:
# bem106

# %% [markdown]
# You can use basic math operators to add strings together and make a longer string, either with + or *

# %%
print(bem + bem)
print(bem*10)

# %% [markdown]
# There are functions that perform actions that you may need when working with strings:
# * `capitalize()`, makes the first character uppercase
# * `lower()`, makes the entire string lowercase
# * `upper()`, makes the entire string uppercase
# * `title()`, capitalizes every word in a string

# %%
print(bem.capitalize())
print(bem.lower())
print(bem.upper())
bem2 = bem+" and " +bem
print(bem2.title())

# %% [markdown]
# What if we want to get rid off specific characters?
#
# * `strip`, deletes characters everywhere
# * `lstrip`, deletes characters from the left

# %%
test = "When is the "+bem +" lecture today?"
print(test)
print(test.lstrip("today?"))
print(test.strip("today?"))
print(test.lstrip("When "))
print(test.strip("When "))

# %% [markdown]
# We can also easily check whether the contents of string are either all alphabetical or numeric.

# %%
test.isalpha() #note that test includes both numbers (106) and characters

# %%
test.isnumeric() #note that test includes both numbers (106) and characters

# %%
"234".isnumeric() # string only includes numbers
# Out:
# True

# %%
"bem".isalpha() # string only includes characters

# %% [markdown]
# ### Slicing a string
#
# We can get an element from a string with slicing
#
# The syntax for slicing is deceptively simple, the full syntax is:
#
# `variable[start_index : stop_index : step]`
#
# You'll see that all of the inputs go within the `[]` and the `:` separates each input.
#
# The `start_index` tells python which index we want to start getting elements from. The first element is denoted by 0.
#
# The `stop_index` tells python which index we want elements **up to but not including**
#
# The `step` tells python how many steps to take between elements within the range. This means that you don't need to take every element. You could take **every other** element. To do that you just specify a `step` of `2`.
#
# Python allows you to access elements by counting from the end of the string too.
#
# When counting from the end, you use negative indicies. The index **`-1`** denotes the last character in a string.

# %%
print(bem[1])
print(bem[1:4])
print(bem[1:10:2])
print(bem[-4:0])
# Out:
# e
# em1
# e16

# %% [markdown]
# ## This is the end of the python/Jupyter basics tutorial.
# Next up: brief homework exercises.

# %% [markdown]
# # Homework exercises: introduction to Pandas
#
# The Pandas package allows you to manipulate spreadsheet-type data, like a company's stock price over time.
#
# ## Benefits of Pandas
#
# 1. Pandas easily handles reading in and outputing CSV/Excel files.
# 2. Pandas takes care of many type conversions after reading a file.
# 3. Accessing data from a Pandas dataframe is intuitive.
# 4. Using Pandas is like working with SQL, which is something you'll encounter if you continue to program.
#
# Additional reading to get you started:
#
# The Pandas tutorial pages http://pandas.pydata.org/pandas-docs/stable/tutorials.html
#
# 10 minutes to Pandas http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# In this and future homeworks, I will provide you with prompts of what your code needs to accomplish. I expect you to reseach and investigate the answers on your own. Each block of code will be a seperate "Exercise" to keep things sequential and organized. Before jumping in to Pandas, I suggest that you research how to create and access the other data types in python: lists, tuples, sets, and dictionaries.

# %% [markdown]
# ### Exercise 1: Import Pandas

# %%
## Import the package and any other packages that we need
## (note: you may need to load more packages after you go through all 8 exercises)
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# ### Exercise 2: Read in the Excel file of CEO/median worker pay

# %%
##  Read in the hw1-ceo-pay excel file.
file = pd.read_excel('hw1-ceo-pay.xlsx')

# %% [markdown]
# Pandas reads in a `CSV`  or Excel files and it turns them into its own data structure called a `Dataframe`. This `Dataframe` is actually a Python class, you can think of it as just a type of *object*. Our data is inside this *object* and it controls how we can interact with it.

# %% [markdown]
# ### Exercise 3: The basics of a dataframe
#
# A `Dataframe` has two basic ways to access values inside of it.
#
# The **columns** run across the **top**
#
# The **indices** run down the **left** (for now, you can think of these as rows)
#
# We can get see the variables by calling them by name from the `dataframe`

# %%
# Access/Print the column names
col_names = file.columns
display(col_names)

# Access/Print the row/index names
row_names = file.index
display(row_names)
# Out:
# Index(['Company Name', 'CEO', 'Median Worker', 'CEO Annual Pay',
#        'Pay Ratio (Cash)', 'Total CEO Compenstation',
#        '% CEO Comp that is cash'],
#       dtype='object')
# RangeIndex(start=0, stop=168, step=1)

# %% [markdown]
# ### Exercise 4: Accessing Data in Pandas
#
# You can access a column using two ways: either by typing the name of the column after the dataframe name, and the other way is similar to accessing a key in a dictionary.

# %%
# Access/Print the column that lists median worker pay through its column name
median_worker = file['Median Worker']
display(median_worker)

# Access/Print the column that lists the CEO name through key-in-dictionary way
CEO_name = file.CEO
display(CEO_name)
# Out:
# 0       27900
# 1       59900
# 2       71400
# 3       22400
# 4       54800
#         ...
# 163    117000
# 164     70500
# 165    109000
# 166    109000
# 167    106000
# Name: Median Worker, Length: 168, dtype: int64
# 0         Larry J. Merlo
# 1         Leslie Moonves
# 2         Robert A. Iger
# 3        Carol Meyrowitz
# 4      K. Rupert Murdoch
#              ...
# 163     Marissa A. Mayer
# 164        Omar M. Asali
# 165         Mark V. Hurd
# 166        Safra A. Catz
# 167       Frank Slootman
# Name: CEO, Length: 168, dtype: object

# %% [markdown]
# ### Exercise 5: Accessing indeces/rows

# %%
# Access/Print the first three rows
first_3rows = file.head(3)
display(first_3rows)

# Access/Print the last column
last_col = file[file.columns[-1]]
display(last_col)

## Access/Print all rows where TOtal CEO Compensation is above $20mil
rows_above20mil = file[file['Total CEO Compenstation'] > 20000000]
display(rows_above20mil)
# Out:
#       Company Name             CEO  Median Worker  CEO Annual Pay  \
# 0  CVS Health Corp  Larry J. Merlo          27900        12105481
# 1         CBS Corp  Leslie Moonves          59900        23652883
# 2  Walt Disney CO/  Robert A. Iger          71400        26208003
#
#       Pay Ratio (Cash)  Total CEO Compenstation  % CEO Comp that is cash
# 0  1900-01-18 02:01:00                 22855374                     0.53
# 1  1900-01-16 11:01:00                 56352801                     0.42
# 2  1900-01-15 07:01:00                 43490567                     0.60
# 0      0.53
# 1      0.42
# 2      0.60
# 3      0.41
# 4      0.77
#        ...
# 163    0.04
# 164    0.06
# 165    0.02
# 166    0.02
# 167    0.05
# Name: % CEO Comp that is cash, Length: 168, dtype: float64
#                             Company Name                    CEO  \
# 0                        CVS Health Corp         Larry J. Merlo
# 1                               CBS Corp         Leslie Moonves
# 2                        Walt Disney CO/         Robert A. Iger
# 4         Twenty-First Century Fox, Inc.      K. Rupert Murdoch
# 5                           Comcast Corp       Brian L. Roberts
# 6                         L Brands, Inc.       Leslie H. Wexner
# 7            Honeywell International Inc          David M. Cote
# 8                            Pepsico Inc         Indra K. Nooyi
# 9                       Wynn Resorts Ltd        Stephen A. Wynn
# 11                          Allergan Plc    Brenton L. Saunders
# 12                           Viacom Inc.     Philippe P. Dauman
# 13          Cablevision Systems Corp /NY         James L. Dolan
# 14   Liberty Media & Liberty Interactive      Gregory B. Maffei
# 18                        Starbucks Corp         Howard Schultz
# 20                   General Electric Co      Jeffrey R. Immelt
# 21                      Time Warner Inc.      Jeffrey L. Bewkes
# 23                     T-Mobile Us, Inc.         John J. Legere
# 24                     Omnicom Group Inc           John D. Wren
# 25        Discovery Communications, Inc.        David M. Zaslav
# 27                  Lockheed Martin Corp     Marillyn A. Hewson
# 31                          Centene Corp    Michael F. Neidorff
# 33                        Morgan Stanley        James P. Gorman
# 35                             AT&T Inc.  Randall L. Stephenson
# 36                               Aramark           Eric J. Foss
# 43         Universal Health Services Inc         Alan B. Miller
# 46                  Dow Chemical Co /DE/      Andrew N. Liveris
# 51                 General Dynamics Corp     Phebe N. Novakovic
# 55                         Blackrock Inc       Laurence D. Fink
# 58               Goldman Sachs Group Inc     Lloyd C. Blankfein
# 68             IMS Health Holdings, Inc.            Ari Bousbib
# 69                     General Motors Co          Mary T. Barra
# 71                     Johnson & Johnson            Alex Gorsky
# 94       General Growth Properties, Inc.       Sandeep Mathrani
# 97                               Aon Plc        Gregory C. Case
# 105                     Exxon Mobil Corp       Rex W. Tillerson
# 106       Lyondellbasell Industries N.V.       Bhavesh V. Patel
# 112                   Salesforce Com Inc           Marc Benioff
# 124        Regeneron Pharmaceuticals Inc   Leonard S. Schleifer
# 140     Tempur Sealy International, Inc.      Scott L. Thompson
# 147                        Expedia, Inc.      Dara Khosrowshahi
# 152                  American Express Co    Kenneth I. Chenault
# 163                            Yahoo Inc       Marissa A. Mayer
# 165                          Oracle Corp           Mark V. Hurd
# 166                          Oracle Corp          Safra A. Catz
#
#      Median Worker  CEO Annual Pay     Pay Ratio (Cash)  \
# 0            27900        12105481  1900-01-18 02:01:00
# 1            59900        23652883  1900-01-16 11:01:00
# 2            71400        26208003  1900-01-15 07:01:00
# 4            54800        17047636  1900-01-12 23:01:00
# 5            55800        16819942  1900-01-12 13:01:00
# 6            33900         9665925  1900-01-11 21:01:00
# 7            81600        22767851  1900-01-11 15:01:00
# 8            61500        15937828  1900-01-10 19:01:00
# 9            50100        11930391  1900-01-09 22:01:00
# 11           92900        21565325  1900-01-09 16:01:00
# 12           79400        18263525  1900-01-09 14:01:00
# 13           62000        13649028  1900-01-09 04:01:00
# 14           51100        10947607  1900-01-08 22:01:00
# 18           28000         5722076  1900-01-08 12:01:00
# 20           86400        17434376  1900-01-08 10:01:00
# 21           78200        15610633  1900-01-08 08:01:00
# 23           60700        10782502  1900-01-07 10:01:00
# 24           84300        13496047  1900-01-06 16:01:00
# 25           68100        10614934  1900-01-06 12:01:00
# 27           76200        11200254  1900-01-06 03:01:00
# 31           60100         8423903  1900-01-05 20:01:00
# 33           80100        10716160  1900-01-05 14:01:00
# 35           59400         7794762  1900-01-05 11:01:00
# 36           42300         5546823  1900-01-05 11:01:00
# 43           54600         6373857  1900-01-04 21:01:00
# 46           76600         8266471  1900-01-04 12:01:00
# 51           68800         6712056  1900-01-04 02:01:00
# 55          103000         9813000  1900-01-03 23:01:00
# 58           93100         8677074  1900-01-03 21:01:00
# 68           84600         6918921  1900-01-03 10:01:00
# 69           65700         5409618  1900-01-03 10:01:00
# 71           73700         5825173  1900-01-03 07:01:00
# 94           64100         4247574  1900-01-02 18:01:00
# 97           65500         4183138  1900-01-02 16:01:00
# 105         101000         5973291  1900-01-02 11:01:00
# 106          95100         5585273  1900-01-02 11:01:00
# 112         109000         6099882  1900-01-02 08:01:00
# 124          80400         4154608  1900-01-02 04:01:00
# 140          56800         2458105  1900-01-01 19:01:00
# 147          95300         3757950  1900-01-01 15:01:00
# 152          87800         2785433  1900-01-01 08:01:00
# 163         117000         1549836             13:01:00
# 165         109000          972253             09:01:00
# 166         109000          970795             09:01:00
#
#      Total CEO Compenstation  % CEO Comp that is cash
# 0                   22855374                     0.53
# 1                   56352801                     0.42
# 2                   43490567                     0.60
# 4                   22192923                     0.77
# 5                   27520744                     0.61
# 6                   26669306                     0.36
# 7                   33105851                     0.69
# 8                   22189307                     0.72
# 9                   20680391                     0.58
# 11                  21565325                     1.00
# 12                  54140509                     0.34
# 13                  24539725                     0.56
# 14                  26868931                     0.41
# 18                  20091353                     0.28
# 20                  26637142                     0.65
# 21                  31493211                     0.50
# 23                  24457987                     0.44
# 24                  23576047                     0.57
# 25                  32377346                     0.33
# 27                  20163169                     0.56
# 31                  20755103                     0.41
# 33                  21966480                     0.49
# 35                  22417776                     0.35
# 36                  21136908                     0.26
# 43                  20427309                     0.31
# 46                  21428875                     0.39
# 51                  20424104                     0.33
# 55                  25792630                     0.38
# 58                  22586152                     0.38
# 68                  34529628                     0.20
# 69                  28576651                     0.19
# 71                  21081598                     0.28
# 94                  39247558                     0.11
# 97                  29735220                     0.14
# 105                 24261291                     0.25
# 106                 24460363                     0.23
# 112                 33362903                     0.18
# 124                 47462526                     0.09
# 140                 23288619                     0.11
# 147                 94603552                     0.04
# 152                 21687566                     0.13
# 163                 35981107                     0.04
# 165                 53245128                     0.02
# 166                 53243670                     0.02

# %% [markdown]
# ### Exercise 6: Slicing in Pandas
#
# There are two other ways of accessing data in pandas, using the .loc and .iloc methods.
#
# * .iloc is integer based and works on the index
# * .loc is strictly label based

# %%
## Access the 100-104 rows and the column names 
rows_100_104 = file.iloc[100:105, :]
display(rows_100_104)

### Access the index label

## Reindex the dataframe to have the Company Name as the new index
file.set_index("Company Name", inplace = True)
display(file)

## Access the following companies through the .loc method (after re-indexing): Aramark, Blackrock Inc, Cigna Corp
companies_ABC = file.loc[["Aramark", "Blackrock Inc", "Cigna Corp"], :]
display(companies_ABC)
# Out:
#                  Company Name                  CEO  Median Worker  \
# 100            Borgwarner Inc     James R. Verrier          85300
# 101  Delta Air Lines Inc /DE/  Richard H. Anderson          69600
# 102        Nextera Energy Inc        James L. Robo          77900
# 103              Nasdaq, Inc.      Robert Greifeld          87700
# 104                     3M Co       Inge G. Thulin          74600
#
#      CEO Annual Pay     Pay Ratio (Cash)  Total CEO Compenstation  \
# 100         5306064  1900-01-02 14:01:00                 17442331
# 101         4341800  1900-01-02 14:01:00                 15842450
# 102         4788297  1900-01-02 13:01:00                 14683608
# 103         5279180  1900-01-02 12:01:00                 14706445
# 104         4501972  1900-01-02 12:01:00                 15499898
#
#      % CEO Comp that is cash
# 100                     0.30
# 101                     0.27
# 102                     0.33
# 103                     0.36
# 104                     0.29
#                                               CEO  Median Worker  \
# Company Name
# CVS Health Corp                    Larry J. Merlo          27900
# CBS Corp                           Leslie Moonves          59900
# Walt Disney CO/                    Robert A. Iger          71400
# TJX Companies Inc /DE/            Carol Meyrowitz          22400
# Twenty-First Century Fox, Inc.  K. Rupert Murdoch          54800
# ...                                           ...            ...
# Yahoo Inc                        Marissa A. Mayer         117000
# HRG Group                           Omar M. Asali          70500
# Oracle Corp                          Mark V. Hurd         109000
# Oracle Corp                         Safra A. Catz         109000
# Servicenow, Inc.                   Frank Slootman         106000
#
#                                 CEO Annual Pay     Pay Ratio (Cash)  \
# Company Name
# CVS Health Corp                       12105481  1900-01-18 02:01:00
# CBS Corp                              23652883  1900-01-16 11:01:00
# Walt Disney CO/                       26208003  1900-01-15 07:01:00
# TJX Companies Inc /DE/                 7330584  1900-01-13 15:01:00
# Twenty-First Century Fox, Inc.        17047636  1900-01-12 23:01:00
# ...                                        ...                  ...
# Yahoo Inc                              1549836             13:01:00
# HRG Group                               721000             10:01:00
# Oracle Corp                             972253             09:01:00
# Oracle Corp                             970795             09:01:00
# Servicenow, Inc.                        642133             06:01:00
#
#                                 Total CEO Compenstation  \
# Company Name
# CVS Health Corp                                22855374
# CBS Corp                                       56352801
# Walt Disney CO/                                43490567
# TJX Companies Inc /DE/                         17962232
# Twenty-First Century Fox, Inc.                 22192923
# ...                                                 ...
# Yahoo Inc                                      35981107
# HRG Group                                      12879177
# Oracle Corp                                    53245128
# Oracle Corp                                    53243670
# Servicenow, Inc.                               12302933
#
#                                 % CEO Comp that is cash
# Company Name
# CVS Health Corp                                    0.53
# CBS Corp                                           0.42
# Walt Disney CO/                                    0.60
# TJX Companies Inc /DE/                             0.41
# Twenty-First Century Fox, Inc.                     0.77
# ...                                                 ...
# Yahoo Inc                                          0.04
# HRG Group                                          0.06
# Oracle Corp                                        0.02
# Oracle Corp                                        0.02
# Servicenow, Inc.                                   0.05
#
# [168 rows x 6 columns]
#                             CEO  Median Worker  CEO Annual Pay  \
# Company Name
# Aramark            Eric J. Foss          42300         5546823
# Blackrock Inc  Laurence D. Fink         103000         9813000
# Cigna Corp     David M. Cordani          62100         4402567
#
#                   Pay Ratio (Cash)  Total CEO Compenstation  \
# Company Name
# Aramark        1900-01-05 11:01:00                 21136908
# Blackrock Inc  1900-01-03 23:01:00                 25792630
# Cigna Corp     1900-01-02 23:01:00                 17307672
#
#                % CEO Comp that is cash
# Company Name
# Aramark                           0.26
# Blackrock Inc                     0.38
# Cigna Corp                        0.25

# %% [markdown]
# ### Exercise 7: Basic data plots

# %%
## Generate a scatterplot with x-axis being median worker pay and y-axis CEO Total compensation
file.plot(kind='scatter', x='Median Worker', y='Total CEO Compenstation')

## Print the correlation between median worker pay CEO Total compensation
correlation = file['Median Worker'].corr(file['Total CEO Compenstation'])
print("correlation between median worker pay CEO Total compensation: " + str(correlation))

## Run a regression (with a constant) of median worker pay on CEO Total Compensation
const = sm.add_constant(file['Median Worker'])
model = sm.OLS(file['Total CEO Compenstation'], const).fit()
display(model.summary())

## Plot your regression line on the scatterplot
plt.plot(file['Median Worker'], model.predict(const), color='red', label='Regression line')
plt.show()

## Generate a histogram of % CEO compensation that is cash
file['% CEO Comp that is cash'].hist(bins = 20, edgecolor = "black")
plt.show
# Out:
# correlation between median worker pay CEO Total compensation: 0.1399754863165025
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Total CEO Compenstation   R-squared:                       0.020
# Model:                                 OLS   Adj. R-squared:                  0.014
# Method:                      Least Squares   F-statistic:                     3.317
# Date:                     Sun, 14 Apr 2024   Prob (F-statistic):             0.0703
# Time:                             13:11:47   Log-Likelihood:                -2943.5
# No. Observations:                      168   AIC:                             5891.
# Df Residuals:                          166   BIC:                             5897.
# Df Model:                                1
# Covariance Type:                 nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.46e+07   2.77e+06      5.264      0.000    9.12e+06    2.01e+07
# Median Worker    65.3692     35.890      1.821      0.070      -5.490     136.228
# ==============================================================================
# Omnibus:                      168.014   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3241.493
# Skew:                           3.791   Prob(JB):                         0.00
# Kurtosis:                      23.139   Cond. No.                     2.81e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Exercise 8: Advanced data plots

# %%
## Create a pie plot of total ceo compensation of all CEOs whose first name is "Jeffrey"
file_Jeffrey = file[file.CEO.str.startswith("Jeffrey")]
plt.pie(file_Jeffrey['Total CEO Compenstation'], labels = file_Jeffrey['Total CEO Compenstation'], autopct='%1.1f%%')
plt.show()

## Create a histogram of the first letter in CEO last names
last_names = file.CEO.str.split().str[-1]
plt.hist(last_names.str[0], edgecolor = "black", bins = 22)
plt.show()

## Create a stacked bar plot where the x-axis is the decile (0-10%, 10-20%, etc) of %CEO Comp that is cash and the y-axis is median worker pay and total ceo compensation.
x = pd.qcut(file['% CEO Comp that is cash'], q=10, labels=False)
plt.bar(x, file['Median Worker'], label = 'Median Worker Pay', color = "blue")
plt.bar(x, file['Total CEO Compenstation'], bottom = file['Median Worker'],label = ' Total CEO Compensation', color="orange")
plt.legend()
